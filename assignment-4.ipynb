# %% [markdown]
# ## 1) Develop a cryptography app in python.

# %%
pip install Cryptography
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from cryptography.fernet import Fernet

# %%
def genratePassKey():
    key = Fernet.generate_key()
    print(key)
    print(type(key))
    abc = open("PasswordKey.key",'wb')
    abc.write(key)
    abc.close()

# %%
genratePassKey()
# Out:
# b'_kvIMlf1CkStJk1coCSLEAp8K-9AFeOQo2b0Y1NfFaA='
# <class 'bytes'>

# %%
def getMyKey():
    abc = open("PasswordKey.key",'rb')
    return abc.read()

# %%
getMyKey()
# Out:
# b'_kvIMlf1CkStJk1coCSLEAp8K-9AFeOQo2b0Y1NfFaA='

# %%
def getContentFromUser():
    return input("Enter the Content you want to Encrypt in your python Script")

# %%
getContentFromUser()
# Out:
# Enter the Content you want to Encrypt in your python ScriptHey I am Kashyap
# 'Hey I am Kashyap'

# %%
def encryptMessage(message_normal):
    key = getMyKey()
    k = Fernet(key)
    encrypted_Message = k.encrypt(message_normal)
    return encrypted_Message

# %%
encryptMessage(b" HEY THIS IS MY ATM NUMBER 734451")
# Out:
# b'gAAAAABf_Ff9u5ZR3IgxLF7GY2QXrn_1m4Ut1Jh5GHksMVaky3ZZBrT8_6HLghfkzSXpaRJQvV3q4w7AZJN5J79MyJlcJ-QVpEsPEe76zXlD6lH7cohx_P1VSQI2rXoW62UURa3ILVEe'

# %%
def decryptMessage(message_secret):
    key = getMyKey()
    k = Fernet(key)
    decrypted_Message = k.decrypt(message_secret)
    return decrypted_Message

# %%
decryptMessage(b'gAAAAABf_Ff9u5ZR3IgxLF7GY2QXrn_1m4Ut1Jh5GHksMVaky3ZZBrT8_6HLghfkzSXpaRJQvV3q4w7AZJN5J79MyJlcJ-QVpEsPEe76zXlD6lH7cohx_P1VSQI2rXoW62UURa3ILVEe')
# Out:
# b' HEY THIS IS MY ATM NUMBER 734451'

# %% [markdown]
# ## 2) Guess the movie name in python.

# %%
pip install firebase_admin
# Out:
# ...
#      |████████████████████████████████| 111 kB 4.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import firebase_admin
from firebase_admin import credentials
c=credentials.Certificate("../input/kashyap/py-letsupgrade-firebase-adminsdk-fc91e-f1819f863b.json")
firebase_admin.initialize_app(c)
print("Working")
# Out:
# Working

# %%
from firebase_admin import firestore

# %%
db=firestore.client()
doc_ref=db.collection("movies").document("Bollywood")
data={"Name":['KGF',"War"],
     "Collection":[100,200]}
doc_ref.set(data)
print("done")
# Out:
# done

# %%
db=firestore.client()
docs=db.collection("movies").stream()
for d in docs:
    #print(d.to_dict())
    d=d.to_dict()

# %%
data=d["Name"]

# %% [markdown]
# # 1_Guess the movie

# %%
import random
count=4
movie=d["Name"]
player=input("Write your name:")
print("Guess the character:")
print("You have only",count, "chance to get the movie name:")
print("Best of Luck:",player)
guess=""
word=random.choice(movie)
while count>0:
    fail=0
    for char in word:
        if char in guess:
            print(char)
        else:
            print("_")
            fail+=1
    if fail==0:
        print("You Won!!")
        print("Movie is:",word)
        break
    g=input("Enter your character:")
    guess=guess+g
    
    if g not in word:
        count-=1
        print("Oops! Wrong Answer:(")
        print("You have",count,"more guesses")
# Out:
# Write your name:k
# Guess the character:
# You have only 4 chance to get the movie name:
# Best of Luck: k
# _
# _
# _
# Enter your character:W
# W
# _
# _
# Enter your character:a
# W
# a
# _
# Enter your character:r
# W
# a
# r
# You Won!!
# Movie is: War

# %% [markdown]
# ## 4) Sending mail using Python.

# %%
pip install instaloader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install emails
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from smtplib import *

# %%
import emails

# %%
sender = 'sarvak88@gmail.com'
receivers = ['xofiyom477@sofiarae.com']

message = """From: From Person <sarvak88@gmail.com>
To: To Person <xofiyom477@sofiarae.com>
Subject: SMTP E-mail Test

This is a test e-mail message.
"""

try:
   smtpObj = smtplib.SMTP('smtp.gmail.com',587)
   smtpObj.sendmail(sender, receivers, message)         
   print("Successfully sent email")
except SMTPException:
    print("Error: unable to send email")
    smtpObj.quit()
# Out:
# Error: unable to send email
