# %% [markdown]
# ## 1) Find the value of the following questions, Where x=5

# %% [markdown]
# ## a) (2x+5/x^2+5x+6)

# %%
x = 5
y =(2*x+5/x**2+5*x+6)

# %%
y
# Out:
# 41.2

# %% [markdown]
# ## b) (x^2+5x+6/2x+5)

# %%
x = 5
y = (x**2+5*x+6/2*x+5)
y
# Out:
# 70.0

# %% [markdown]
# ## c) (2x-3)(x-9)

# %%
x = 5
y = (2*x-3)*(x-9)

# %%
y
# Out:
# -28

# %% [markdown]
# ## 2) Create a username and password login file using nested while loop

# %%
print('Enter correct username and password combo to continue')
count=0
while count < 3:
    username = input('Enter username: ')
    password = input('Enter password: ')
    if password!=0 and username!=0:
        print('Access granted')
        break
    else:
        print('Access denied. Try again.')
        count += 1
# Out:
# Enter correct username and password combo to continue
# Enter username:  kashyap
# Enter password:  kashyap
# Access granted
